# %%
#time module for time.time()
import time
import sys
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
"""
combine 
Mergesort with Insertion Sort to come up with a hybrid sorting algorithm for better 
efficiency. The idea is to set a small integer S as a threshold for the size of subarrays. 
Once the size of a subarray in a recursive call of Mergesort is less than or equal to S, 
the algorithm will switch to Insertion Sort, which is efficient for small-sized input
"""


keyComparisons=0
def driver(inputSize,THRESHOLD):
    
    if(THRESHOLD==0):
        return -1
    
    global keyComparisons
    
    keyComparisons=0
    

    array = np.random.randint(1,inputSize,inputSize)
    
    array=array.tolist()

    #sorted = hybridSort(array,THRESHOLD)
    start_time = time.time()
    #sorted=mergeSort(array,0,len(array)-1)
    sorted=hybridSort(array,THRESHOLD)
    print("--- %s seconds ---" % (time.time() - start_time))
    
    print("The number of keyComparisons is ",end="")
    print(keyComparisons)

    return keyComparisons
    
    
    
def hybridSort(array,THRESHOLD):
    #THRESHOLD CANNOT BE 0 else the below condition will never take place and will result in infinite loop
    if len(array) <=THRESHOLD:
        insertionSort(array)
        return array
    else:
        mid=len(array)//2
        firsthalf = array[:mid]
        secondhalf = array[mid:]
        left = hybridSort(firsthalf,THRESHOLD)
        right = hybridSort(secondhalf,THRESHOLD)
        final=merge(left,right)
        return final


def merge(left,right):
    global keyComparisons
    final=[]
    leftIndex=0
    rightIndex=0
    length_left=len(left)
    length_right=len(right)
    while leftIndex < length_left and rightIndex < length_right:
        if left[leftIndex] <= right[rightIndex]:
            final.append(left[leftIndex])
            leftIndex+=1
            keyComparisons+=1
        else:
            final.append(right[rightIndex])
            rightIndex+=1
            keyComparisons+=1
        
    #if there are elements left over in left half, just copy over everything
    while leftIndex < length_left:
        final.append(left[leftIndex])
        leftIndex += 1
        
    #if there are elements left over in right half, just copy over everything
    while rightIndex < length_right:
        final.append(right[rightIndex])
        rightIndex += 1
        
    #after everything is done    
    return final


def insertionSort(array):
    global keyComparisons
    for i in range(1,len(array),1):
        for j in range(i,0,-1):
            if array[j]< array[j-1]:
                keyComparisons += 1
                array[j],array[j-1]=array[j-1],array[j]
            else:
                keyComparisons += 1
                break
            

#vanilla mergesort as a benchmark
def mergesort(array):
    if len(array) == 1:
        return array
    else:
        final =[]
        firsthalf = array[:len(array)//2]
        secondhalf = array[len(array)//2:]
        sub1 = mergesort(firsthalf)
        sub2 = mergesort(secondhalf)
        final=merge(sub1,sub2)
        return final

# %%
results={}
inputSize=1000
THRESHOLD=20
while inputSize < 1_000_000:
    print(f"The input size is {inputSize}")
    
    
    
    #run the driver function and save the results into a dictionary
    results[inputSize]=driver(inputSize,THRESHOLD)
    #driver(inputSize)
    
    
    inputSize+=1000

# %%
plots=pd.DataFrame(results.items(), columns=['inputSize', 'keyComparisons'])
plots

# %%
f=plt.figure(figsize=(7,7))
finish=sb.lineplot(x=plots["inputSize"],y=plots["keyComparisons"])
n_values = plots["inputSize"]
nlogn_values = n_values * np.log(n_values)

# Plot the nlog(n) curve
plt.plot(n_values, nlogn_values, label="nlog(n)", color='red')

# %% [markdown]
# **Conclusion**: The shape our graph matches the theoretical shape

# %% [markdown]
# For part 2 we will fix the input size n at 1_000_000 and try different values of S, the threshold for which insertion sort is used over mergesort.

# %%
results2={}
inputSize=10_000
THRESHOLD = 1
while THRESHOLD < inputSize:
    print("hello")
    print(f"The THRESHOLD size is {THRESHOLD}")
    
    #run the driver function and save the results into a dictionary
    results2[THRESHOLD]=driver(inputSize,THRESHOLD)
#     #driver(inputSize)
    
    THRESHOLD+=5
# Out:
# hello
# The THRESHOLD size is 1
# --- 0.056989431381225586 seconds ---
# The number of keyComparisons is 120483
# hello
# The THRESHOLD size is 6
# --- 0.04882240295410156 seconds ---
# The number of keyComparisons is 121489
# hello
# The THRESHOLD size is 11
# --- 0.041547536849975586 seconds ---
# The number of keyComparisons is 126972
# hello
# The THRESHOLD size is 16
# --- 0.043401241302490234 seconds ---
# The number of keyComparisons is 127064
# hello
# The THRESHOLD size is 21
# --- 0.045285701751708984 seconds ---
# The number of keyComparisons is 143320
# hello
# The THRESHOLD size is 26
# --- 0.05303025245666504 seconds ---
# The number of keyComparisons is 143267
# hello
# The THRESHOLD size is 31
# --- 0.04798722267150879 seconds ---
# The number of keyComparisons is 143280
# hello
# The THRESHOLD size is 36
# --- 0.04282188415527344 seconds ---
# The number of keyComparisons is 143579
# hello
# The THRESHOLD size is 41
# --- 0.06251907348632812 seconds ---
# The number of keyComparisons is 181747
# hello
# The THRESHOLD size is 46
# --- 0.06461143493652344 seconds ---
# The number of keyComparisons is 184109
# hello
# The THRESHOLD size is 51
# --- 0.06353878974914551 seconds ---
# The number of keyComparisons is 183642
# hello
# The THRESHOLD size is 56
# --- 0.04688596725463867 seconds ---
# The number of keyComparisons is 184953
# hello
# The THRESHOLD size is 61
# --- 0.06290936470031738 seconds ---
# The number of keyComparisons is 182611
# hello
# The THRESHOLD size is 66
# --- 0.0764014720916748 seconds ---
# The number of keyComparisons is 182817
# hello
# The THRESHOLD size is 71
# --- 0.06277656555175781 seconds ---
# The number of keyComparisons is 184446
# hello
# The THRESHOLD size is 76
# --- 0.06093406677246094 seconds ---
# The number of keyComparisons is 182819
# hello
# The THRESHOLD size is 81
# --- 0.09317779541015625 seconds ---
# The number of keyComparisons is 272261
# hello
# The THRESHOLD size is 86
# --- 0.10538983345031738 seconds ---
# The number of keyComparisons is 271942
# hello
# The THRESHOLD size is 91
# --- 0.08747291564941406 seconds ---
# The number of keyComparisons is 273688
# hello
# The THRESHOLD size is 96
# --- 0.09300804138183594 seconds ---
# The number of keyComparisons is 271420
# hello
# The THRESHOLD size is 101
# --- 0.08868575096130371 seconds ---
# The number of keyComparisons is 270533
# hello
# The THRESHOLD size is 106
# --- 0.09175658226013184 seconds ---
# The number of keyComparisons is 271294
# hello
# The THRESHOLD size is 111
# --- 0.09207320213317871 seconds ---
# The number of keyComparisons is 272664
# hello
# The THRESHOLD size is 116
# --- 0.09268856048583984 seconds ---
# The number of keyComparisons is 272084
# hello
# The THRESHOLD size is 121
# --- 0.07671117782592773 seconds ---
# The number of keyComparisons is 272292
# hello
# The THRESHOLD size is 126
# --- 0.08986425399780273 seconds ---
# The number of keyComparisons is 272702
# hello
# The THRESHOLD size is 131
# --- 0.08686399459838867 seconds ---
# The number of keyComparisons is 272433
# hello
# The THRESHOLD size is 136
# --- 0.08626413345336914 seconds ---
# The number of keyComparisons is 271102
# hello
# The THRESHOLD size is 141
# --- 0.07751917839050293 seconds ---
# The number of keyComparisons is 271182
# hello
# The THRESHOLD size is 146
# --- 0.09811782836914062 seconds ---
# The number of keyComparisons is 272160
# hello
# The THRESHOLD size is 151
# --- 0.09205818176269531 seconds ---
# The number of keyComparisons is 273493
# hello
# The THRESHOLD size is 156
# --- 0.13140559196472168 seconds ---
# The number of keyComparisons is 412489
# hello
# The THRESHOLD size is 161
# --- 0.14157581329345703 seconds ---
# The number of keyComparisons is 461546
# hello
# The THRESHOLD size is 166
# --- 0.14819812774658203 seconds ---
# The number of keyComparisons is 461444
# hello
# The THRESHOLD size is 171
# --- 0.14162850379943848 seconds ---
# The number of keyComparisons is 454602
# hello
# The THRESHOLD size is 176
# --- 0.15575718879699707 seconds ---
# The number of keyComparisons is 459926
# hello
# The THRESHOLD size is 181
# --- 0.14638423919677734 seconds ---
# The number of keyComparisons is 455954
# hello
# The THRESHOLD size is 186
# --- 0.1428232192993164 seconds ---
# The number of keyComparisons is 456470
# hello
# The THRESHOLD size is 191
# --- 0.16390275955200195 seconds ---
# The number of keyComparisons is 457597
# hello
# The THRESHOLD size is 196
# --- 0.15750956535339355 seconds ---
# The number of keyComparisons is 461790
# hello
# The THRESHOLD size is 201
# --- 0.15308570861816406 seconds ---
# The number of keyComparisons is 459971
# hello
# The THRESHOLD size is 206
# --- 0.1459951400756836 seconds ---
# The number of keyComparisons is 458029
# hello
# The THRESHOLD size is 211
# --- 0.15913105010986328 seconds ---
# The number of keyComparisons is 460218
# hello
# The THRESHOLD size is 216
# --- 0.15582895278930664 seconds ---
# The number of keyComparisons is 459187
# hello
# The THRESHOLD size is 221
# --- 0.15068483352661133 seconds ---
# The number of keyComparisons is 456770
# hello
# The THRESHOLD size is 226
# --- 0.15196657180786133 seconds ---
# The number of keyComparisons is 460628
# hello
# The THRESHOLD size is 231
# --- 0.14467644691467285 seconds ---
# The number of keyComparisons is 456529
# hello
# The THRESHOLD size is 236
# --- 0.15623712539672852 seconds ---
# The number of keyComparisons is 459473
# hello
# The THRESHOLD size is 241
# --- 0.14363932609558105 seconds ---
# The number of keyComparisons is 457346
# hello
# The THRESHOLD size is 246
# --- 0.14763736724853516 seconds ---
# The number of keyComparisons is 458159
# hello
# The THRESHOLD size is 251
# --- 0.13734054565429688 seconds ---
# The number of keyComparisons is 456380
# hello
# The THRESHOLD size is 256
# --- 0.1370394229888916 seconds ---
# The number of keyComparisons is 455461
# hello
# The THRESHOLD size is 261
# --- 0.1535336971282959 seconds ---
# The number of keyComparisons is 455247
# hello
# The THRESHOLD size is 266
# --- 0.1539013385772705 seconds ---
# The number of keyComparisons is 457075
# hello
# The THRESHOLD size is 271
# --- 0.14184069633483887 seconds ---
# The number of keyComparisons is 458131
# hello
# The THRESHOLD size is 276
# --- 0.1431879997253418 seconds ---
# The number of keyComparisons is 461561
# hello
# The THRESHOLD size is 281
# --- 0.16398358345031738 seconds ---
# The number of keyComparisons is 457403
# hello
# The THRESHOLD size is 286
# --- 0.15897488594055176 seconds ---
# The number of keyComparisons is 463564
# hello
# The THRESHOLD size is 291
# --- 0.1470482349395752 seconds ---
# The number of keyComparisons is 458392
# hello
# The THRESHOLD size is 296
# --- 0.15184569358825684 seconds ---
# The number of keyComparisons is 453989
# hello
# The THRESHOLD size is 301
# --- 0.15579581260681152 seconds ---
# The number of keyComparisons is 454888
# hello
# The THRESHOLD size is 306
# --- 0.1361081600189209 seconds ---
# The number of keyComparisons is 454552
# hello
# The THRESHOLD size is 311
# --- 0.14909720420837402 seconds ---
# The number of keyComparisons is 460388
# hello
# The THRESHOLD size is 316
# --- 0.27028322219848633 seconds ---
# The number of keyComparisons is 830476
# hello
# The THRESHOLD size is 321
# --- 0.2814047336578369 seconds ---
# The number of keyComparisons is 836379
# hello
# The THRESHOLD size is 326
# --- 0.27961158752441406 seconds ---
# The number of keyComparisons is 838877
# hello
# The THRESHOLD size is 331
# --- 0.2890889644622803 seconds ---
# The number of keyComparisons is 840547
# hello
# The THRESHOLD size is 336
# --- 0.28296327590942383 seconds ---
# The number of keyComparisons is 844853
# hello
# The THRESHOLD size is 341
# --- 0.26542115211486816 seconds ---
# The number of keyComparisons is 838212
# hello
# The THRESHOLD size is 346
# --- 0.2707967758178711 seconds ---
# The number of keyComparisons is 841392
# hello
# The THRESHOLD size is 351
# --- 0.29950380325317383 seconds ---
# The number of keyComparisons is 841411
# hello
# The THRESHOLD size is 356
# --- 0.27173733711242676 seconds ---
# The number of keyComparisons is 833385
# hello
# The THRESHOLD size is 361
# --- 0.28632497787475586 seconds ---
# The number of keyComparisons is 845014
# hello
# The THRESHOLD size is 366
# --- 0.2467503547668457 seconds ---
# The number of keyComparisons is 844367
# hello
# The THRESHOLD size is 371
# --- 0.22486495971679688 seconds ---
# The number of keyComparisons is 838063
# hello
# The THRESHOLD size is 376
# --- 0.19079136848449707 seconds ---
# The number of keyComparisons is 828251
# hello
# The THRESHOLD size is 381
# --- 0.1939849853515625 seconds ---
# The number of keyComparisons is 839524
# hello
# The THRESHOLD size is 386
# --- 0.18932557106018066 seconds ---
# The number of keyComparisons is 833464
# hello
# The THRESHOLD size is 391
# --- 0.21205544471740723 seconds ---
# The number of keyComparisons is 841057
# hello
# The THRESHOLD size is 396
# --- 0.19288229942321777 seconds ---
# The number of keyComparisons is 838324
# hello
# The THRESHOLD size is 401
# --- 0.2056577205657959 seconds ---
# The number of keyComparisons is 840533
# hello
# The THRESHOLD size is 406
# --- 0.20809197425842285 seconds ---
# The number of keyComparisons is 844389
# hello
# The THRESHOLD size is 411
# --- 0.2215268611907959 seconds ---
# The number of keyComparisons is 843403
# hello
# The THRESHOLD size is 416
# --- 0.2055511474609375 seconds ---
# The number of keyComparisons is 842608
# hello
# The THRESHOLD size is 421
# --- 0.19612765312194824 seconds ---
# The number of keyComparisons is 832446
# hello
# The THRESHOLD size is 426
# --- 0.20520234107971191 seconds ---
# The number of keyComparisons is 840814
# hello
# The THRESHOLD size is 431
# --- 0.19751548767089844 seconds ---
# The number of keyComparisons is 841425
# hello
# The THRESHOLD size is 436
# --- 0.18843817710876465 seconds ---
# The number of keyComparisons is 825697
# hello
# The THRESHOLD size is 441
# --- 0.20710325241088867 seconds ---
# The number of keyComparisons is 845300
# hello
# The THRESHOLD size is 446
# --- 0.18832778930664062 seconds ---
# The number of keyComparisons is 835731
# hello
# The THRESHOLD size is 451
# --- 0.19809293746948242 seconds ---
# The number of keyComparisons is 829396
# hello
# The THRESHOLD size is 456
# --- 0.18793869018554688 seconds ---
# The number of keyComparisons is 835805
# hello
# The THRESHOLD size is 461
# --- 0.2140331268310547 seconds ---
# The number of keyComparisons is 847648
# hello
# The THRESHOLD size is 466
# --- 0.20379137992858887 seconds ---
# The number of keyComparisons is 837937
# hello
# The THRESHOLD size is 471
# --- 0.19785332679748535 seconds ---
# The number of keyComparisons is 841002
# hello
# The THRESHOLD size is 476
# --- 0.20401453971862793 seconds ---
# The number of keyComparisons is 833942
# hello
# The THRESHOLD size is 481
# --- 0.19145488739013672 seconds ---
# The number of keyComparisons is 834210
# hello
# The THRESHOLD size is 486
# --- 0.2040715217590332 seconds ---
# The number of keyComparisons is 834660
# hello
# The THRESHOLD size is 491
# --- 0.20049452781677246 seconds ---
# The number of keyComparisons is 840790
# hello
# The THRESHOLD size is 496
# --- 0.20401263236999512 seconds ---
# The number of keyComparisons is 835996
# hello
# The THRESHOLD size is 501
# --- 0.197998046875 seconds ---
# The number of keyComparisons is 840829
# hello
# The THRESHOLD size is 506
# --- 0.18838930130004883 seconds ---
# The number of keyComparisons is 838740
# hello
# The THRESHOLD size is 511
# --- 0.2096867561340332 seconds ---
# The number of keyComparisons is 839809
# hello
# The THRESHOLD size is 516
# --- 0.1888427734375 seconds ---
# The number of keyComparisons is 835661
# hello
# The THRESHOLD size is 521
# --- 0.21323347091674805 seconds ---
# The number of keyComparisons is 833494
# hello
# The THRESHOLD size is 526
# --- 0.1886885166168213 seconds ---
# The number of keyComparisons is 839837
# hello
# The THRESHOLD size is 531
# --- 0.21167707443237305 seconds ---
# The number of keyComparisons is 832120
# hello
# The THRESHOLD size is 536
# --- 0.18635177612304688 seconds ---
# The number of keyComparisons is 828771
# hello
# The THRESHOLD size is 541
# --- 0.19659090042114258 seconds ---
# The number of keyComparisons is 829695
# hello
# The THRESHOLD size is 546
# --- 0.20401239395141602 seconds ---
# The number of keyComparisons is 840836
# hello
# The THRESHOLD size is 551
# --- 0.19426584243774414 seconds ---
# The number of keyComparisons is 838009
# hello
# The THRESHOLD size is 556
# --- 0.19475793838500977 seconds ---
# The number of keyComparisons is 831304
# hello
# The THRESHOLD size is 561
# --- 0.20566558837890625 seconds ---
# The number of keyComparisons is 839378
# hello
# The THRESHOLD size is 566
# --- 0.19503998756408691 seconds ---
# The number of keyComparisons is 834752
# hello
# The THRESHOLD size is 571
# --- 0.2049098014831543 seconds ---
# The number of keyComparisons is 844109
# hello
# The THRESHOLD size is 576
# --- 0.19607806205749512 seconds ---
# The number of keyComparisons is 832801
# hello
# The THRESHOLD size is 581
# --- 0.20037841796875 seconds ---
# The number of keyComparisons is 847543
# hello
# The THRESHOLD size is 586
# --- 0.20247554779052734 seconds ---
# The number of keyComparisons is 840272
# hello
# The THRESHOLD size is 591
# --- 0.19887781143188477 seconds ---
# The number of keyComparisons is 835021
# hello
# The THRESHOLD size is 596
# --- 0.20446014404296875 seconds ---
# The number of keyComparisons is 834951
# hello
# The THRESHOLD size is 601
# --- 0.1966838836669922 seconds ---
# The number of keyComparisons is 835177
# hello
# The THRESHOLD size is 606
# --- 0.19780826568603516 seconds ---
# The number of keyComparisons is 837049
# hello
# The THRESHOLD size is 611
# --- 0.18535685539245605 seconds ---
# The number of keyComparisons is 836172
# hello
# The THRESHOLD size is 616
# --- 0.18954205513000488 seconds ---
# The number of keyComparisons is 843052
# hello
# The THRESHOLD size is 621
# --- 0.19549036026000977 seconds ---
# The number of keyComparisons is 832062
# hello
# The THRESHOLD size is 626
# --- 0.3944370746612549 seconds ---
# The number of keyComparisons is 1599181
# hello
# The THRESHOLD size is 631
# --- 0.4030787944793701 seconds ---
# The number of keyComparisons is 1605102
# hello
# The THRESHOLD size is 636
# --- 0.4012322425842285 seconds ---
# The number of keyComparisons is 1629058
# hello
# The THRESHOLD size is 641
# --- 0.3837108612060547 seconds ---
# The number of keyComparisons is 1602826
# hello
# The THRESHOLD size is 646
# --- 0.4040079116821289 seconds ---
# The number of keyComparisons is 1605618
# hello
# The THRESHOLD size is 651
# --- 0.401317834854126 seconds ---
# The number of keyComparisons is 1606641
# hello
# The THRESHOLD size is 656
# --- 0.3945741653442383 seconds ---
# The number of keyComparisons is 1619142
# hello
# The THRESHOLD size is 661
# --- 0.4004979133605957 seconds ---
# The number of keyComparisons is 1611051
# hello
# The THRESHOLD size is 666
# --- 0.39539217948913574 seconds ---
# The number of keyComparisons is 1605217
# hello
# The THRESHOLD size is 671
# --- 0.40580224990844727 seconds ---
# The number of keyComparisons is 1616745
# hello
# The THRESHOLD size is 676
# --- 0.38255882263183594 seconds ---
# The number of keyComparisons is 1595917
# hello
# The THRESHOLD size is 681
# --- 0.4096951484680176 seconds ---
# The number of keyComparisons is 1618641
# hello
# The THRESHOLD size is 686
# --- 0.38975024223327637 seconds ---
# The number of keyComparisons is 1605230
# hello
# The THRESHOLD size is 691
# --- 0.39511966705322266 seconds ---
# The number of keyComparisons is 1600700
# hello
# The THRESHOLD size is 696
# --- 0.39423489570617676 seconds ---
# The number of keyComparisons is 1612464
# hello
# The THRESHOLD size is 701
# --- 0.40981221199035645 seconds ---
# The number of keyComparisons is 1619197
# hello
# The THRESHOLD size is 706
# --- 0.3842792510986328 seconds ---
# The number of keyComparisons is 1609593
# hello
# The THRESHOLD size is 711
# --- 0.3945608139038086 seconds ---
# The number of keyComparisons is 1607437
# hello
# The THRESHOLD size is 716
# --- 0.39496469497680664 seconds ---
# The number of keyComparisons is 1607156
# hello
# The THRESHOLD size is 721
# --- 0.3915736675262451 seconds ---
# The number of keyComparisons is 1596332
# hello
# The THRESHOLD size is 726
# --- 0.3809826374053955 seconds ---
# The number of keyComparisons is 1604582
# hello
# The THRESHOLD size is 731
# --- 0.40346646308898926 seconds ---
# The number of keyComparisons is 1598910
# hello
# The THRESHOLD size is 736
# --- 0.43021273612976074 seconds ---
# The number of keyComparisons is 1610602
# hello
# The THRESHOLD size is 741
# --- 0.3881251811981201 seconds ---
# The number of keyComparisons is 1622855
# hello
# The THRESHOLD size is 746
# --- 0.41207337379455566 seconds ---
# The number of keyComparisons is 1615965
# hello
# The THRESHOLD size is 751
# --- 0.3902308940887451 seconds ---
# The number of keyComparisons is 1618960
# hello
# The THRESHOLD size is 756
# --- 0.4029271602630615 seconds ---
# The number of keyComparisons is 1605743
# hello
# The THRESHOLD size is 761
# --- 0.39313769340515137 seconds ---
# The number of keyComparisons is 1602302
# hello
# The THRESHOLD size is 766
# --- 0.40746021270751953 seconds ---
# The number of keyComparisons is 1606372
# hello
# The THRESHOLD size is 771
# --- 0.42215538024902344 seconds ---
# The number of keyComparisons is 1627162
# hello
# The THRESHOLD size is 776
# --- 0.40872788429260254 seconds ---
# The number of keyComparisons is 1601353
# hello
# The THRESHOLD size is 781
# --- 0.4215719699859619 seconds ---
# The number of keyComparisons is 1619635
# hello
# The THRESHOLD size is 786
# --- 0.4062643051147461 seconds ---
# The number of keyComparisons is 1606746
# hello
# The THRESHOLD size is 791
# --- 0.42699217796325684 seconds ---
# The number of keyComparisons is 1614314
# hello
# The THRESHOLD size is 796
# --- 0.40746164321899414 seconds ---
# The number of keyComparisons is 1601262
# hello
# The THRESHOLD size is 801
# --- 0.39876317977905273 seconds ---
# The number of keyComparisons is 1610845
# hello
# The THRESHOLD size is 806
# --- 0.4044535160064697 seconds ---
# The number of keyComparisons is 1624191
# hello
# The THRESHOLD size is 811
# --- 0.3976607322692871 seconds ---
# The number of keyComparisons is 1600588
# hello
# The THRESHOLD size is 816
# --- 0.4003770351409912 seconds ---
# The number of keyComparisons is 1592633
# hello
# The THRESHOLD size is 821
# --- 0.4000835418701172 seconds ---
# The number of keyComparisons is 1601985
# hello
# The THRESHOLD size is 826
# --- 0.39476513862609863 seconds ---
# The number of keyComparisons is 1609458
# hello
# The THRESHOLD size is 831
# --- 0.40706658363342285 seconds ---
# The number of keyComparisons is 1593174
# hello
# The THRESHOLD size is 836
# --- 0.40854477882385254 seconds ---
# The number of keyComparisons is 1626224
# hello
# The THRESHOLD size is 841
# --- 0.3987436294555664 seconds ---
# The number of keyComparisons is 1607353
# hello
# The THRESHOLD size is 846
# --- 0.41478657722473145 seconds ---
# The number of keyComparisons is 1590698
# hello
# The THRESHOLD size is 851
# --- 0.42009449005126953 seconds ---
# The number of keyComparisons is 1624169
# hello
# The THRESHOLD size is 856
# --- 0.4308450222015381 seconds ---
# The number of keyComparisons is 1616494
# hello
# The THRESHOLD size is 861
# --- 0.4227011203765869 seconds ---
# The number of keyComparisons is 1591989
# hello
# The THRESHOLD size is 866
# --- 0.42133188247680664 seconds ---
# The number of keyComparisons is 1613731
# hello
# The THRESHOLD size is 871
# --- 0.38492512702941895 seconds ---
# The number of keyComparisons is 1597761
# hello
# The THRESHOLD size is 876
# --- 0.3999156951904297 seconds ---
# The number of keyComparisons is 1611466
# hello
# The THRESHOLD size is 881
# --- 0.3925211429595947 seconds ---
# The number of keyComparisons is 1593230
# hello
# The THRESHOLD size is 886
# --- 0.4412574768066406 seconds ---
# The number of keyComparisons is 1627268
# hello
# The THRESHOLD size is 891
# --- 0.41974902153015137 seconds ---
# The number of keyComparisons is 1608886
# hello
# The THRESHOLD size is 896
# --- 0.4059641361236572 seconds ---
# The number of keyComparisons is 1611364
# hello
# The THRESHOLD size is 901
# --- 0.40519285202026367 seconds ---
# The number of keyComparisons is 1636938
# hello
# The THRESHOLD size is 906
# --- 0.42334914207458496 seconds ---
# The number of keyComparisons is 1608926
# hello
# The THRESHOLD size is 911
# --- 0.41657114028930664 seconds ---
# The number of keyComparisons is 1605012
# hello
# The THRESHOLD size is 916
# --- 0.41791272163391113 seconds ---
# The number of keyComparisons is 1616318
# hello
# The THRESHOLD size is 921
# --- 0.40082430839538574 seconds ---
# The number of keyComparisons is 1614657
# hello
# The THRESHOLD size is 926
# --- 0.3951683044433594 seconds ---
# The number of keyComparisons is 1595404
# hello
# The THRESHOLD size is 931
# --- 0.4091758728027344 seconds ---
# The number of keyComparisons is 1612555
# hello
# The THRESHOLD size is 936
# --- 0.40539073944091797 seconds ---
# The number of keyComparisons is 1616378
# hello
# The THRESHOLD size is 941
# --- 0.42122387886047363 seconds ---
# The number of keyComparisons is 1589986
# hello
# The THRESHOLD size is 946
# --- 0.5168914794921875 seconds ---
# The number of keyComparisons is 1623647
# hello
# The THRESHOLD size is 951
# --- 0.43020009994506836 seconds ---
# The number of keyComparisons is 1596187
# hello
# The THRESHOLD size is 956
# --- 0.4137730598449707 seconds ---
# The number of keyComparisons is 1621466
# hello
# The THRESHOLD size is 961
# --- 0.43880319595336914 seconds ---
# The number of keyComparisons is 1624955
# hello
# The THRESHOLD size is 966
# --- 0.4057924747467041 seconds ---
# The number of keyComparisons is 1599524
# hello
# The THRESHOLD size is 971
# --- 0.4331061840057373 seconds ---
# The number of keyComparisons is 1625404
# hello
# The THRESHOLD size is 976
# --- 0.3919248580932617 seconds ---
# The number of keyComparisons is 1601688
# hello
# The THRESHOLD size is 981
# --- 0.39996862411499023 seconds ---
# The number of keyComparisons is 1608434
# hello
# The THRESHOLD size is 986
# --- 0.47913336753845215 seconds ---
# The number of keyComparisons is 1611303
# hello
# The THRESHOLD size is 991
# --- 0.42087411880493164 seconds ---
# The number of keyComparisons is 1604422
# hello
# The THRESHOLD size is 996
# --- 0.4035654067993164 seconds ---
# The number of keyComparisons is 1620582
# hello
# The THRESHOLD size is 1001
# --- 0.41275525093078613 seconds ---
# The number of keyComparisons is 1620319
# hello
# The THRESHOLD size is 1006
# --- 0.4293944835662842 seconds ---
# The number of keyComparisons is 1615809
# hello
# The THRESHOLD size is 1011
# --- 0.4057149887084961 seconds ---
# The number of keyComparisons is 1592364
# hello
# The THRESHOLD size is 1016
# --- 0.41512584686279297 seconds ---
# The number of keyComparisons is 1603345
# hello
# The THRESHOLD size is 1021
# --- 0.4106485843658447 seconds ---
# The number of keyComparisons is 1592756
# hello
# The THRESHOLD size is 1026
# --- 0.4447753429412842 seconds ---
# The number of keyComparisons is 1611025
# hello
# The THRESHOLD size is 1031
# --- 0.4823322296142578 seconds ---
# The number of keyComparisons is 1606374
# hello
# The THRESHOLD size is 1036
# --- 0.45244622230529785 seconds ---
# The number of keyComparisons is 1609693
# hello
# The THRESHOLD size is 1041
# --- 0.4676203727722168 seconds ---
# The number of keyComparisons is 1626863
# hello
# The THRESHOLD size is 1046
# --- 0.4418764114379883 seconds ---
# The number of keyComparisons is 1627118
# hello
# The THRESHOLD size is 1051
# --- 0.46779775619506836 seconds ---
# The number of keyComparisons is 1590529
# hello
# The THRESHOLD size is 1056
# --- 0.4192655086517334 seconds ---
# The number of keyComparisons is 1622444
# hello
# The THRESHOLD size is 1061
# --- 0.42629218101501465 seconds ---
# The number of keyComparisons is 1593895
# hello
# The THRESHOLD size is 1066
# --- 0.43927669525146484 seconds ---
# The number of keyComparisons is 1614765
# hello
# The THRESHOLD size is 1071
# --- 0.4004373550415039 seconds ---
# The number of keyComparisons is 1609752
# hello
# The THRESHOLD size is 1076
# --- 0.4299812316894531 seconds ---
# The number of keyComparisons is 1607519
# hello
# The THRESHOLD size is 1081
# --- 0.4228508472442627 seconds ---
# The number of keyComparisons is 1607098
# hello
# The THRESHOLD size is 1086
# --- 0.46857547760009766 seconds ---
# The number of keyComparisons is 1611577
# hello
# The THRESHOLD size is 1091
# --- 0.45153141021728516 seconds ---
# The number of keyComparisons is 1593215
# hello
# The THRESHOLD size is 1096
# --- 0.520796537399292 seconds ---
# The number of keyComparisons is 1635549
# hello
# The THRESHOLD size is 1101
# --- 0.4264202117919922 seconds ---
# The number of keyComparisons is 1615105
# hello
# The THRESHOLD size is 1106
# --- 0.44040656089782715 seconds ---
# The number of keyComparisons is 1627016
# hello
# The THRESHOLD size is 1111
# --- 0.4571497440338135 seconds ---
# The number of keyComparisons is 1614754
# hello
# The THRESHOLD size is 1116
# --- 0.4101386070251465 seconds ---
# The number of keyComparisons is 1596261
# hello
# The THRESHOLD size is 1121
# --- 0.40810179710388184 seconds ---
# The number of keyComparisons is 1614721
# hello
# The THRESHOLD size is 1126
# --- 0.4096260070800781 seconds ---
# The number of keyComparisons is 1607263
# hello
# The THRESHOLD size is 1131
# --- 0.42138218879699707 seconds ---
# The number of keyComparisons is 1611253
# hello
# The THRESHOLD size is 1136
# --- 0.4000587463378906 seconds ---
# The number of keyComparisons is 1598645
# hello
# The THRESHOLD size is 1141
# --- 0.40767717361450195 seconds ---
# The number of keyComparisons is 1607780
# hello
# The THRESHOLD size is 1146
# --- 0.40581774711608887 seconds ---
# The number of keyComparisons is 1605656
# hello
# The THRESHOLD size is 1151
# --- 0.41741418838500977 seconds ---
# The number of keyComparisons is 1606181
# hello
# The THRESHOLD size is 1156
# --- 0.39643359184265137 seconds ---
# The number of keyComparisons is 1604163
# hello
# The THRESHOLD size is 1161
# --- 0.40172624588012695 seconds ---
# The number of keyComparisons is 1624397
# hello
# The THRESHOLD size is 1166
# --- 0.4026165008544922 seconds ---
# The number of keyComparisons is 1618562
# hello
# The THRESHOLD size is 1171
# --- 0.4064161777496338 seconds ---
# The number of keyComparisons is 1615599
# hello
# The THRESHOLD size is 1176
# --- 0.40700840950012207 seconds ---
# The number of keyComparisons is 1613256
# hello
# The THRESHOLD size is 1181
# --- 0.4156324863433838 seconds ---
# The number of keyComparisons is 1610591
# hello
# The THRESHOLD size is 1186
# --- 0.4015169143676758 seconds ---
# The number of keyComparisons is 1611302
# hello
# The THRESHOLD size is 1191
# --- 0.41063857078552246 seconds ---
# The number of keyComparisons is 1621926
# hello
# The THRESHOLD size is 1196
# --- 0.40473198890686035 seconds ---
# The number of keyComparisons is 1604994
# hello
# The THRESHOLD size is 1201
# --- 0.40639615058898926 seconds ---
# The number of keyComparisons is 1618015
# hello
# The THRESHOLD size is 1206
# --- 0.4005410671234131 seconds ---
# The number of keyComparisons is 1594246
# hello
# The THRESHOLD size is 1211
# --- 0.4096696376800537 seconds ---
# The number of keyComparisons is 1603436
# hello
# The THRESHOLD size is 1216
# --- 0.4014883041381836 seconds ---
# The number of keyComparisons is 1607482
# hello
# The THRESHOLD size is 1221
# --- 0.40689659118652344 seconds ---
# The number of keyComparisons is 1615732
# hello
# The THRESHOLD size is 1226
# --- 0.4058678150177002 seconds ---
# The number of keyComparisons is 1608663
# hello
# The THRESHOLD size is 1231
# --- 0.41085243225097656 seconds ---
# The number of keyComparisons is 1593813
# hello
# The THRESHOLD size is 1236
# --- 0.3995704650878906 seconds ---
# The number of keyComparisons is 1619117
# hello
# The THRESHOLD size is 1241
# --- 0.40861034393310547 seconds ---
# The number of keyComparisons is 1609169
# hello
# The THRESHOLD size is 1246
# --- 0.4008145332336426 seconds ---
# The number of keyComparisons is 1605652
# hello
# The THRESHOLD size is 1251
# --- 0.8012874126434326 seconds ---
# The number of keyComparisons is 3150997
# hello
# The THRESHOLD size is 1256
# --- 0.794966459274292 seconds ---
# The number of keyComparisons is 3117770
# hello
# The THRESHOLD size is 1261
# --- 0.8007283210754395 seconds ---
# The number of keyComparisons is 3122793
# hello
# The THRESHOLD size is 1266
# --- 0.8104021549224854 seconds ---
# The number of keyComparisons is 3159485
# hello
# The THRESHOLD size is 1271
# --- 0.8162307739257812 seconds ---
# The number of keyComparisons is 3178501
# hello
# The THRESHOLD size is 1276
# --- 0.8069560527801514 seconds ---
# The number of keyComparisons is 3161235
# hello
# The THRESHOLD size is 1281
# --- 0.8038535118103027 seconds ---
# The number of keyComparisons is 3144489
# hello
# The THRESHOLD size is 1286
# --- 0.8305060863494873 seconds ---
# The number of keyComparisons is 3153331
# hello
# The THRESHOLD size is 1291
# --- 0.8689780235290527 seconds ---
# The number of keyComparisons is 3181783
# hello
# The THRESHOLD size is 1296
# --- 0.8448464870452881 seconds ---
# The number of keyComparisons is 3147750
# hello
# The THRESHOLD size is 1301
# --- 0.8532865047454834 seconds ---
# The number of keyComparisons is 3190955
# hello
# The THRESHOLD size is 1306
# --- 0.8260612487792969 seconds ---
# The number of keyComparisons is 3147004
# hello
# The THRESHOLD size is 1311
# --- 0.8394112586975098 seconds ---
# The number of keyComparisons is 3161004
# hello
# The THRESHOLD size is 1316
# --- 0.8707327842712402 seconds ---
# The number of keyComparisons is 3163060
# hello
# The THRESHOLD size is 1321
# --- 0.8580272197723389 seconds ---
# The number of keyComparisons is 3191077
# hello
# The THRESHOLD size is 1326
# --- 0.850135087966919 seconds ---
# The number of keyComparisons is 3160747
# hello
# The THRESHOLD size is 1331
# --- 0.8572132587432861 seconds ---
# The number of keyComparisons is 3188953
# hello
# The THRESHOLD size is 1336
# --- 0.8287849426269531 seconds ---
# The number of keyComparisons is 3154654
# hello
# The THRESHOLD size is 1341
# --- 0.8678643703460693 seconds ---
# The number of keyComparisons is 3173914
# hello
# The THRESHOLD size is 1346
# --- 0.8202838897705078 seconds ---
# The number of keyComparisons is 3169680
# hello
# The THRESHOLD size is 1351
# --- 0.8673181533813477 seconds ---
# The number of keyComparisons is 3163686
# hello
# The THRESHOLD size is 1356
# --- 0.876784086227417 seconds ---
# The number of keyComparisons is 3153948
# hello
# The THRESHOLD size is 1361
# --- 0.9127826690673828 seconds ---
# The number of keyComparisons is 3156491
# hello
# The THRESHOLD size is 1366
# --- 0.833418607711792 seconds ---
# The number of keyComparisons is 3157170
# hello
# The THRESHOLD size is 1371
# --- 0.8613231182098389 seconds ---
# The number of keyComparisons is 3160765
# hello
# The THRESHOLD size is 1376
# --- 0.8538773059844971 seconds ---
# The number of keyComparisons is 3155804
# hello
# The THRESHOLD size is 1381
# --- 0.8197834491729736 seconds ---
# The number of keyComparisons is 3147028
# hello
# The THRESHOLD size is 1386
# --- 0.8405132293701172 seconds ---
# The number of keyComparisons is 3190855
# hello
# The THRESHOLD size is 1391
# --- 0.8119716644287109 seconds ---
# The number of keyComparisons is 3155352
# hello
# The THRESHOLD size is 1396
# --- 0.8389632701873779 seconds ---
# The number of keyComparisons is 3147923
# hello
# The THRESHOLD size is 1401
# --- 0.8403303623199463 seconds ---
# The number of keyComparisons is 3128213
# hello
# The THRESHOLD size is 1406
# --- 0.8425159454345703 seconds ---
# The number of keyComparisons is 3123604
# hello
# The THRESHOLD size is 1411
# --- 0.8496320247650146 seconds ---
# The number of keyComparisons is 3168617
# hello
# The THRESHOLD size is 1416
# --- 0.8519072532653809 seconds ---
# The number of keyComparisons is 3157282
# hello
# The THRESHOLD size is 1421
# --- 0.8513846397399902 seconds ---
# The number of keyComparisons is 3169049
# hello
# The THRESHOLD size is 1426
# --- 0.8621346950531006 seconds ---
# The number of keyComparisons is 3158477
# hello
# The THRESHOLD size is 1431
# --- 0.8351531028747559 seconds ---
# The number of keyComparisons is 3157904
# hello
# The THRESHOLD size is 1436
# --- 0.815321683883667 seconds ---
# The number of keyComparisons is 3181413
# hello
# The THRESHOLD size is 1441
# --- 0.8188810348510742 seconds ---
# The number of keyComparisons is 3172322
# hello
# The THRESHOLD size is 1446
# --- 0.8762836456298828 seconds ---
# The number of keyComparisons is 3194386
# hello
# The THRESHOLD size is 1451
# --- 0.8634676933288574 seconds ---
# The number of keyComparisons is 3157169
# hello
# The THRESHOLD size is 1456
# --- 0.8740675449371338 seconds ---
# The number of keyComparisons is 3203845
# hello
# The THRESHOLD size is 1461
# --- 0.844202995300293 seconds ---
# The number of keyComparisons is 3158521
# hello
# The THRESHOLD size is 1466
# --- 0.8410873413085938 seconds ---
# The number of keyComparisons is 3153798
# hello
# The THRESHOLD size is 1471
# --- 0.8820369243621826 seconds ---
# The number of keyComparisons is 3209652
# hello
# The THRESHOLD size is 1476
# --- 0.8695414066314697 seconds ---
# The number of keyComparisons is 3166430
# hello
# The THRESHOLD size is 1481
# --- 0.8308823108673096 seconds ---
# The number of keyComparisons is 3151344
# hello
# The THRESHOLD size is 1486
# --- 0.8449757099151611 seconds ---
# The number of keyComparisons is 3142287
# hello
# The THRESHOLD size is 1491
# --- 0.841768741607666 seconds ---
# The number of keyComparisons is 3159192
# hello
# The THRESHOLD size is 1496
# --- 0.8705341815948486 seconds ---
# The number of keyComparisons is 3151887
# hello
# The THRESHOLD size is 1501
# --- 0.8211703300476074 seconds ---
# The number of keyComparisons is 3151237
# hello
# The THRESHOLD size is 1506
# --- 0.8581867218017578 seconds ---
# The number of keyComparisons is 3140095
# hello
# The THRESHOLD size is 1511
# --- 0.8655343055725098 seconds ---
# The number of keyComparisons is 3178600
# hello
# The THRESHOLD size is 1516
# --- 0.861614465713501 seconds ---
# The number of keyComparisons is 3163174
# hello
# The THRESHOLD size is 1521
# --- 0.8171231746673584 seconds ---
# The number of keyComparisons is 3128402
# hello
# The THRESHOLD size is 1526
# --- 0.8280456066131592 seconds ---
# The number of keyComparisons is 3164394
# hello
# The THRESHOLD size is 1531
# --- 0.8362565040588379 seconds ---
# The number of keyComparisons is 3175555
# hello
# The THRESHOLD size is 1536
# --- 0.8599064350128174 seconds ---
# The number of keyComparisons is 3177452
# hello
# The THRESHOLD size is 1541
# --- 0.8637382984161377 seconds ---
# The number of keyComparisons is 3166632
# hello
# The THRESHOLD size is 1546
# --- 0.909735918045044 seconds ---
# The number of keyComparisons is 3152747
# hello
# The THRESHOLD size is 1551
# --- 0.8344542980194092 seconds ---
# The number of keyComparisons is 3174815
# hello
# The THRESHOLD size is 1556
# --- 0.8826110363006592 seconds ---
# The number of keyComparisons is 3176807
# hello
# The THRESHOLD size is 1561
# --- 0.8412489891052246 seconds ---
# The number of keyComparisons is 3167352
# hello
# The THRESHOLD size is 1566
# --- 0.8214695453643799 seconds ---
# The number of keyComparisons is 3174588
# hello
# The THRESHOLD size is 1571
# --- 0.8246860504150391 seconds ---
# The number of keyComparisons is 3141947
# hello
# The THRESHOLD size is 1576
# --- 0.8554298877716064 seconds ---
# The number of keyComparisons is 3122364
# hello
# The THRESHOLD size is 1581
# --- 0.8306000232696533 seconds ---
# The number of keyComparisons is 3132685
# hello
# The THRESHOLD size is 1586
# --- 0.8679404258728027 seconds ---
# The number of keyComparisons is 3164787
# hello
# The THRESHOLD size is 1591
# --- 0.8456056118011475 seconds ---
# The number of keyComparisons is 3170998
# hello
# The THRESHOLD size is 1596
# --- 0.8195738792419434 seconds ---
# The number of keyComparisons is 3111018
# hello
# The THRESHOLD size is 1601
# --- 0.8586280345916748 seconds ---
# The number of keyComparisons is 3173247
# hello
# The THRESHOLD size is 1606
# --- 0.818824052810669 seconds ---
# The number of keyComparisons is 3136306
# hello
# The THRESHOLD size is 1611
# --- 0.8377549648284912 seconds ---
# The number of keyComparisons is 3146894
# hello
# The THRESHOLD size is 1616
# --- 0.8354818820953369 seconds ---
# The number of keyComparisons is 3168458
# hello
# The THRESHOLD size is 1621
# --- 0.8196585178375244 seconds ---
# The number of keyComparisons is 3120685
# hello
# The THRESHOLD size is 1626
# --- 0.8416688442230225 seconds ---
# The number of keyComparisons is 3163265
# hello
# The THRESHOLD size is 1631
# --- 0.869758129119873 seconds ---
# The number of keyComparisons is 3148333
# hello
# The THRESHOLD size is 1636
# --- 0.8397188186645508 seconds ---
# The number of keyComparisons is 3176095
# hello
# The THRESHOLD size is 1641
# --- 0.8429644107818604 seconds ---
# The number of keyComparisons is 3165527
# hello
# The THRESHOLD size is 1646
# --- 0.8458781242370605 seconds ---
# The number of keyComparisons is 3207299
# hello
# The THRESHOLD size is 1651
# --- 0.8548223972320557 seconds ---
# The number of keyComparisons is 3168756
# hello
# The THRESHOLD size is 1656
# --- 0.8524937629699707 seconds ---
# The number of keyComparisons is 3184455
# hello
# The THRESHOLD size is 1661
# --- 0.8706073760986328 seconds ---
# The number of keyComparisons is 3191951
# hello
# The THRESHOLD size is 1666
# --- 0.8264448642730713 seconds ---
# The number of keyComparisons is 3175450
# hello
# The THRESHOLD size is 1671
# --- 0.8432402610778809 seconds ---
# The number of keyComparisons is 3192645
# hello
# The THRESHOLD size is 1676
# --- 0.886066198348999 seconds ---
# The number of keyComparisons is 3161032
# hello
# The THRESHOLD size is 1681
# --- 0.8265955448150635 seconds ---
# The number of keyComparisons is 3152622
# hello
# The THRESHOLD size is 1686
# --- 0.8944997787475586 seconds ---
# The number of keyComparisons is 3122324
# hello
# The THRESHOLD size is 1691
# --- 0.8250265121459961 seconds ---
# The number of keyComparisons is 3197048
# hello
# The THRESHOLD size is 1696
# --- 0.8228123188018799 seconds ---
# The number of keyComparisons is 3146345
# hello
# The THRESHOLD size is 1701
# --- 0.8644421100616455 seconds ---
# The number of keyComparisons is 3151242
# hello
# The THRESHOLD size is 1706
# --- 0.8417186737060547 seconds ---
# The number of keyComparisons is 3155770
# hello
# The THRESHOLD size is 1711
# --- 0.8392622470855713 seconds ---
# The number of keyComparisons is 3191291
# hello
# The THRESHOLD size is 1716
# --- 0.9489490985870361 seconds ---
# The number of keyComparisons is 3193270
# hello
# The THRESHOLD size is 1721
# --- 0.8642013072967529 seconds ---
# The number of keyComparisons is 3159894
# hello
# The THRESHOLD size is 1726
# --- 0.8314058780670166 seconds ---
# The number of keyComparisons is 3173622
# hello
# The THRESHOLD size is 1731
# --- 0.8323557376861572 seconds ---
# The number of keyComparisons is 3134019
# hello
# The THRESHOLD size is 1736
# --- 0.8703093528747559 seconds ---
# The number of keyComparisons is 3147236
# hello
# The THRESHOLD size is 1741
# --- 0.8276708126068115 seconds ---
# The number of keyComparisons is 3165213
# hello
# The THRESHOLD size is 1746
# --- 0.8314170837402344 seconds ---
# The number of keyComparisons is 3155470
# hello
# The THRESHOLD size is 1751
# --- 0.9081082344055176 seconds ---
# The number of keyComparisons is 3200061
# hello
# The THRESHOLD size is 1756
# --- 0.8134860992431641 seconds ---
# The number of keyComparisons is 3172044
# hello
# The THRESHOLD size is 1761
# --- 0.8816287517547607 seconds ---
# The number of keyComparisons is 3137265
# hello
# The THRESHOLD size is 1766
# --- 0.8419671058654785 seconds ---
# The number of keyComparisons is 3136596
# hello
# The THRESHOLD size is 1771
# --- 0.885439395904541 seconds ---
# The number of keyComparisons is 3173602
# hello
# The THRESHOLD size is 1776
# --- 0.8338022232055664 seconds ---
# The number of keyComparisons is 3117036
# hello
# The THRESHOLD size is 1781
# --- 0.8279428482055664 seconds ---
# The number of keyComparisons is 3159279
# hello
# The THRESHOLD size is 1786
# --- 0.864274263381958 seconds ---
# The number of keyComparisons is 3163146
# hello
# The THRESHOLD size is 1791
# --- 0.8562712669372559 seconds ---
# The number of keyComparisons is 3129689
# hello
# The THRESHOLD size is 1796
# --- 0.8331813812255859 seconds ---
# The number of keyComparisons is 3184770
# hello
# The THRESHOLD size is 1801
# --- 0.8141453266143799 seconds ---
# The number of keyComparisons is 3158543
# hello
# The THRESHOLD size is 1806
# --- 0.8558833599090576 seconds ---
# The number of keyComparisons is 3159341
# hello
# The THRESHOLD size is 1811
# --- 0.8916022777557373 seconds ---
# The number of keyComparisons is 3151466
# hello
# The THRESHOLD size is 1816
# --- 0.8222596645355225 seconds ---
# The number of keyComparisons is 3177522
# hello
# The THRESHOLD size is 1821
# --- 0.8339557647705078 seconds ---
# The number of keyComparisons is 3144281
# hello
# The THRESHOLD size is 1826
# --- 0.8384220600128174 seconds ---
# The number of keyComparisons is 3150430
# hello
# The THRESHOLD size is 1831
# --- 0.8478546142578125 seconds ---
# The number of keyComparisons is 3165303
# hello
# The THRESHOLD size is 1836
# --- 0.8270370960235596 seconds ---
# The number of keyComparisons is 3141931
# hello
# The THRESHOLD size is 1841
# --- 0.8287084102630615 seconds ---
# The number of keyComparisons is 3133485
# hello
# The THRESHOLD size is 1846
# --- 0.835848331451416 seconds ---
# The number of keyComparisons is 3122610
# hello
# The THRESHOLD size is 1851
# --- 0.8150219917297363 seconds ---
# The number of keyComparisons is 3114500
# hello
# The THRESHOLD size is 1856
# --- 0.8340117931365967 seconds ---
# The number of keyComparisons is 3184809
# hello
# The THRESHOLD size is 1861
# --- 0.8139543533325195 seconds ---
# The number of keyComparisons is 3139174
# hello
# The THRESHOLD size is 1866
# --- 0.8653502464294434 seconds ---
# The number of keyComparisons is 3186215
# hello
# The THRESHOLD size is 1871
# --- 0.8312418460845947 seconds ---
# The number of keyComparisons is 3137260
# hello
# The THRESHOLD size is 1876
# --- 0.8823192119598389 seconds ---
# The number of keyComparisons is 3165078
# hello
# The THRESHOLD size is 1881
# --- 0.8507075309753418 seconds ---
# The number of keyComparisons is 3156166
# hello
# The THRESHOLD size is 1886
# --- 0.839428186416626 seconds ---
# The number of keyComparisons is 3176600
# hello
# The THRESHOLD size is 1891
# --- 0.8637335300445557 seconds ---
# The number of keyComparisons is 3189867
# hello
# The THRESHOLD size is 1896
# --- 0.8321754932403564 seconds ---
# The number of keyComparisons is 3122036
# hello
# The THRESHOLD size is 1901
# --- 0.8022232055664062 seconds ---
# The number of keyComparisons is 3111391
# hello
# The THRESHOLD size is 1906
# --- 0.8113117218017578 seconds ---
# The number of keyComparisons is 3166129
# hello
# The THRESHOLD size is 1911
# --- 0.8330981731414795 seconds ---
# The number of keyComparisons is 3144088
# hello
# The THRESHOLD size is 1916
# --- 0.8382127285003662 seconds ---
# The number of keyComparisons is 3163087
# hello
# The THRESHOLD size is 1921
# --- 0.8572218418121338 seconds ---
# The number of keyComparisons is 3213669
# hello
# The THRESHOLD size is 1926
# --- 0.8365945816040039 seconds ---
# The number of keyComparisons is 3196059
# hello
# The THRESHOLD size is 1931
# --- 0.8228294849395752 seconds ---
# The number of keyComparisons is 3145833
# hello
# The THRESHOLD size is 1936
# --- 0.8545989990234375 seconds ---
# The number of keyComparisons is 3154733
# hello
# The THRESHOLD size is 1941
# --- 0.834996223449707 seconds ---
# The number of keyComparisons is 3188485
# hello
# The THRESHOLD size is 1946
# --- 0.8139128684997559 seconds ---
# The number of keyComparisons is 3164317
# hello
# The THRESHOLD size is 1951
# --- 0.8244674205780029 seconds ---
# The number of keyComparisons is 3178396
# hello
# The THRESHOLD size is 1956
# --- 0.7954809665679932 seconds ---
# The number of keyComparisons is 3131822
# hello
# The THRESHOLD size is 1961
# --- 0.8325750827789307 seconds ---
# The number of keyComparisons is 3205235
# hello
# The THRESHOLD size is 1966
# --- 0.8498201370239258 seconds ---
# The number of keyComparisons is 3166263
# hello
# The THRESHOLD size is 1971
# --- 0.8452353477478027 seconds ---
# The number of keyComparisons is 3143951
# hello
# The THRESHOLD size is 1976
# --- 0.832700252532959 seconds ---
# The number of keyComparisons is 3157079
# hello
# The THRESHOLD size is 1981
# --- 0.8339090347290039 seconds ---
# The number of keyComparisons is 3138703
# hello
# The THRESHOLD size is 1986
# --- 0.8438839912414551 seconds ---
# The number of keyComparisons is 3199694
# hello
# The THRESHOLD size is 1991
# --- 0.8243463039398193 seconds ---
# The number of keyComparisons is 3177017
# hello
# The THRESHOLD size is 1996
# --- 0.8518826961517334 seconds ---
# The number of keyComparisons is 3152726
# hello
# The THRESHOLD size is 2001
# --- 0.852001428604126 seconds ---
# The number of keyComparisons is 3207131
# hello
# The THRESHOLD size is 2006
# --- 0.8461923599243164 seconds ---
# The number of keyComparisons is 3141902
# hello
# The THRESHOLD size is 2011
# --- 0.8502650260925293 seconds ---
# The number of keyComparisons is 3125791
# hello
# The THRESHOLD size is 2016
# --- 0.8368067741394043 seconds ---
# The number of keyComparisons is 3200581
# hello
# The THRESHOLD size is 2021
# --- 0.828944206237793 seconds ---
# The number of keyComparisons is 3179654
# hello
# The THRESHOLD size is 2026
# --- 0.8865220546722412 seconds ---
# The number of keyComparisons is 3156021
# hello
# The THRESHOLD size is 2031
# --- 0.8679170608520508 seconds ---
# The number of keyComparisons is 3162529
# hello
# The THRESHOLD size is 2036
# --- 0.8507843017578125 seconds ---
# The number of keyComparisons is 3169641
# hello
# The THRESHOLD size is 2041
# --- 0.7994310855865479 seconds ---
# The number of keyComparisons is 3141493
# hello
# The THRESHOLD size is 2046
# --- 0.8366925716400146 seconds ---
# The number of keyComparisons is 3159270
# hello
# The THRESHOLD size is 2051
# --- 0.8316605091094971 seconds ---
# The number of keyComparisons is 3166967
# hello
# The THRESHOLD size is 2056
# --- 0.9118893146514893 seconds ---
# The number of keyComparisons is 3177880
# hello
# The THRESHOLD size is 2061
# --- 0.8207144737243652 seconds ---
# The number of keyComparisons is 3165269
# hello
# The THRESHOLD size is 2066
# --- 0.854698657989502 seconds ---
# The number of keyComparisons is 3186081
# hello
# The THRESHOLD size is 2071
# --- 0.8195571899414062 seconds ---
# The number of keyComparisons is 3183354
# hello
# The THRESHOLD size is 2076
# --- 0.8409895896911621 seconds ---
# The number of keyComparisons is 3150142
# hello
# The THRESHOLD size is 2081
# --- 0.8694825172424316 seconds ---
# The number of keyComparisons is 3206222
# hello
# The THRESHOLD size is 2086
# --- 0.8358078002929688 seconds ---
# The number of keyComparisons is 3163713
# hello
# The THRESHOLD size is 2091
# --- 0.8212974071502686 seconds ---
# The number of keyComparisons is 3140668
# hello
# The THRESHOLD size is 2096
# --- 0.877960205078125 seconds ---
# The number of keyComparisons is 3178399
# hello
# The THRESHOLD size is 2101
# --- 0.803727388381958 seconds ---
# The number of keyComparisons is 3154720
# hello
# The THRESHOLD size is 2106
# --- 0.8418660163879395 seconds ---
# The number of keyComparisons is 3179647
# hello
# The THRESHOLD size is 2111
# --- 0.8228988647460938 seconds ---
# The number of keyComparisons is 3153563
# hello
# The THRESHOLD size is 2116
# --- 0.8281702995300293 seconds ---
# The number of keyComparisons is 3152877
# hello
# The THRESHOLD size is 2121
# --- 0.8495895862579346 seconds ---
# The number of keyComparisons is 3133860
# hello
# The THRESHOLD size is 2126
# --- 0.8367035388946533 seconds ---
# The number of keyComparisons is 3159044
# hello
# The THRESHOLD size is 2131
# --- 0.8500871658325195 seconds ---
# The number of keyComparisons is 3189476
# hello
# The THRESHOLD size is 2136
# --- 0.819861650466919 seconds ---
# The number of keyComparisons is 3172247
# hello
# The THRESHOLD size is 2141
# --- 0.8576526641845703 seconds ---
# The number of keyComparisons is 3193627
# hello
# The THRESHOLD size is 2146
# --- 0.835242509841919 seconds ---
# The number of keyComparisons is 3201558
# hello
# The THRESHOLD size is 2151
# --- 0.8267369270324707 seconds ---
# The number of keyComparisons is 3148430
# hello
# The THRESHOLD size is 2156
# --- 0.8418781757354736 seconds ---
# The number of keyComparisons is 3175696
# hello
# The THRESHOLD size is 2161
# --- 0.8266935348510742 seconds ---
# The number of keyComparisons is 3117293
# hello
# The THRESHOLD size is 2166
# --- 0.8664000034332275 seconds ---
# The number of keyComparisons is 3191891
# hello
# The THRESHOLD size is 2171
# --- 0.8661952018737793 seconds ---
# The number of keyComparisons is 3179790
# hello
# The THRESHOLD size is 2176
# --- 0.8168933391571045 seconds ---
# The number of keyComparisons is 3129731
# hello
# The THRESHOLD size is 2181
# --- 0.827265739440918 seconds ---
# The number of keyComparisons is 3159450
# hello
# The THRESHOLD size is 2186
# --- 0.8450191020965576 seconds ---
# The number of keyComparisons is 3149193
# hello
# The THRESHOLD size is 2191
# --- 0.8098659515380859 seconds ---
# The number of keyComparisons is 3154837
# hello
# The THRESHOLD size is 2196
# --- 0.8183639049530029 seconds ---
# The number of keyComparisons is 3195315
# hello
# The THRESHOLD size is 2201
# --- 0.8163986206054688 seconds ---
# The number of keyComparisons is 3184879
# hello
# The THRESHOLD size is 2206
# --- 0.8381931781768799 seconds ---
# The number of keyComparisons is 3162768
# hello
# The THRESHOLD size is 2211
# --- 0.804962158203125 seconds ---
# The number of keyComparisons is 3105480
# hello
# The THRESHOLD size is 2216
# --- 0.808255672454834 seconds ---
# The number of keyComparisons is 3180750
# hello
# The THRESHOLD size is 2221
# --- 0.8377723693847656 seconds ---
# The number of keyComparisons is 3199990
# hello
# The THRESHOLD size is 2226
# --- 0.8206524848937988 seconds ---
# The number of keyComparisons is 3170954
# hello
# The THRESHOLD size is 2231
# ...
# hello
# The THRESHOLD size is 5961
# --- 3.2665209770202637 seconds ---
# The number of keyComparisons is 12584894
# hello
# The THRESHOLD size is 5966
# --- 3.2690365314483643 seconds ---
# The number of keyComparisons is 12540020
# hello
# The THRESHOLD size is 5971
# --- 3.3187055587768555 seconds ---
# The number of keyComparisons is 12395864
# hello
# The THRESHOLD size is 5976
# --- 3.361065626144409 seconds ---
# The number of keyComparisons is 12584202
# hello
# The THRESHOLD size is 5981
# --- 3.401887893676758 seconds ---
# The number of keyComparisons is 12490079
# hello
# The THRESHOLD size is 5986
# --- 3.2999303340911865 seconds ---
# The number of keyComparisons is 12603172
# hello
# The THRESHOLD size is 5991
# --- 3.3520867824554443 seconds ---
# The number of keyComparisons is 12518997
# hello
# The THRESHOLD size is 5996
# --- 3.3993773460388184 seconds ---
# The number of keyComparisons is 12667050
# hello
# The THRESHOLD size is 6001
# --- 3.3315207958221436 seconds ---
# The number of keyComparisons is 12517785
# hello
# The THRESHOLD size is 6006
# --- 3.3292994499206543 seconds ---
# The number of keyComparisons is 12547667
# hello
# The THRESHOLD size is 6011
# --- 3.294285774230957 seconds ---
# The number of keyComparisons is 12628971
# hello
# The THRESHOLD size is 6016
# --- 3.344353437423706 seconds ---
# The number of keyComparisons is 12467308
# hello
# The THRESHOLD size is 6021
# --- 3.215489149093628 seconds ---
# The number of keyComparisons is 12398405
# hello
# The THRESHOLD size is 6026
# --- 3.333235740661621 seconds ---
# The number of keyComparisons is 12493448
# hello
# The THRESHOLD size is 6031
# --- 3.2284655570983887 seconds ---
# The number of keyComparisons is 12384882
# hello
# The THRESHOLD size is 6036
# --- 3.2582969665527344 seconds ---
# The number of keyComparisons is 12461822
# hello
# The THRESHOLD size is 6041
# --- 3.3295860290527344 seconds ---
# The number of keyComparisons is 12558919
# hello
# The THRESHOLD size is 6046
# --- 3.2380871772766113 seconds ---
# The number of keyComparisons is 12508682
# hello
# The THRESHOLD size is 6051
# --- 3.250899076461792 seconds ---
# The number of keyComparisons is 12503075
# hello
# The THRESHOLD size is 6056
# --- 3.2812085151672363 seconds ---
# The number of keyComparisons is 12582394
# hello
# The THRESHOLD size is 6061
# --- 3.2678072452545166 seconds ---
# The number of keyComparisons is 12441830
# hello
# The THRESHOLD size is 6066
# --- 3.226158857345581 seconds ---
# The number of keyComparisons is 12446639
# hello
# The THRESHOLD size is 6071
# --- 3.192737102508545 seconds ---
# The number of keyComparisons is 12595708
# hello
# The THRESHOLD size is 6076
# --- 3.1668965816497803 seconds ---
# The number of keyComparisons is 12392567
# hello
# The THRESHOLD size is 6081
# --- 3.234426259994507 seconds ---
# The number of keyComparisons is 12475045
# hello
# The THRESHOLD size is 6086
# --- 3.277637243270874 seconds ---
# The number of keyComparisons is 12567922
# hello
# The THRESHOLD size is 6091
# --- 3.3669755458831787 seconds ---
# The number of keyComparisons is 12680616
# hello
# The THRESHOLD size is 6096
# --- 3.229990005493164 seconds ---
# The number of keyComparisons is 12419845
# hello
# The THRESHOLD size is 6101
# --- 3.1679635047912598 seconds ---
# The number of keyComparisons is 12556899
# hello
# The THRESHOLD size is 6106
# --- 3.1707141399383545 seconds ---
# The number of keyComparisons is 12562511
# hello
# The THRESHOLD size is 6111
# --- 3.115774154663086 seconds ---
# The number of keyComparisons is 12338372
# hello
# The THRESHOLD size is 6116
# --- 3.13388991355896 seconds ---
# The number of keyComparisons is 12416017
# hello
# The THRESHOLD size is 6121
# --- 3.2509536743164062 seconds ---
# The number of keyComparisons is 12565914
# hello
# The THRESHOLD size is 6126
# --- 3.197235584259033 seconds ---
# The number of keyComparisons is 12665925
# hello
# The THRESHOLD size is 6131
# --- 3.20525860786438 seconds ---
# The number of keyComparisons is 12562861
# hello
# The THRESHOLD size is 6136
# --- 3.149524211883545 seconds ---
# The number of keyComparisons is 12477334
# hello
# The THRESHOLD size is 6141
# --- 3.216430187225342 seconds ---
# The number of keyComparisons is 12590535
# hello
# The THRESHOLD size is 6146
# --- 3.1739816665649414 seconds ---
# The number of keyComparisons is 12486864
# hello
# The THRESHOLD size is 6151
# --- 3.227909803390503 seconds ---
# The number of keyComparisons is 12563990
# hello
# The THRESHOLD size is 6156
# --- 3.2762608528137207 seconds ---
# The number of keyComparisons is 12574879
# hello
# The THRESHOLD size is 6161
# --- 3.188171625137329 seconds ---
# The number of keyComparisons is 12438020
# hello
# The THRESHOLD size is 6166
# --- 3.151280641555786 seconds ---
# The number of keyComparisons is 12491515
# hello
# The THRESHOLD size is 6171
# --- 3.3487370014190674 seconds ---
# The number of keyComparisons is 12559421
# hello
# The THRESHOLD size is 6176
# --- 3.1767208576202393 seconds ---
# The number of keyComparisons is 12440101
# hello
# The THRESHOLD size is 6181
# --- 3.118407726287842 seconds ---
# The number of keyComparisons is 12502823
# hello
# The THRESHOLD size is 6186
# --- 3.1449389457702637 seconds ---
# The number of keyComparisons is 12414933
# hello
# The THRESHOLD size is 6191
# --- 3.158949613571167 seconds ---
# The number of keyComparisons is 12464321
# hello
# The THRESHOLD size is 6196
# --- 3.216376304626465 seconds ---
# The number of keyComparisons is 12578710
# hello
# The THRESHOLD size is 6201
# --- 3.360927104949951 seconds ---
# The number of keyComparisons is 12383544
# hello
# The THRESHOLD size is 6206
# --- 3.3330726623535156 seconds ---
# The number of keyComparisons is 12532300
# hello
# The THRESHOLD size is 6211
# --- 3.2881598472595215 seconds ---
# The number of keyComparisons is 12508270
# hello
# The THRESHOLD size is 6216
# --- 3.342264413833618 seconds ---
# The number of keyComparisons is 12372643
# hello
# The THRESHOLD size is 6221
# --- 3.299668788909912 seconds ---
# The number of keyComparisons is 12477468
# hello
# The THRESHOLD size is 6226
# --- 3.3085439205169678 seconds ---
# The number of keyComparisons is 12479718
# hello
# The THRESHOLD size is 6231
# --- 3.3735601902008057 seconds ---
# The number of keyComparisons is 12446344
# hello
# The THRESHOLD size is 6236
# --- 3.3880372047424316 seconds ---
# The number of keyComparisons is 12489721
# hello
# The THRESHOLD size is 6241
# --- 3.284473419189453 seconds ---
# The number of keyComparisons is 12650762
# hello
# The THRESHOLD size is 6246
# --- 3.3299930095672607 seconds ---
# The number of keyComparisons is 12395809
# hello
# The THRESHOLD size is 6251
# --- 3.248040199279785 seconds ---
# The number of keyComparisons is 12377737
# hello
# The THRESHOLD size is 6256
# --- 3.2122342586517334 seconds ---
# The number of keyComparisons is 12512952
# hello
# The THRESHOLD size is 6261
# --- 3.4153082370758057 seconds ---
# The number of keyComparisons is 12653755
# hello
# The THRESHOLD size is 6266
# --- 3.2551774978637695 seconds ---
# The number of keyComparisons is 12617421
# hello
# The THRESHOLD size is 6271
# --- 3.2308645248413086 seconds ---
# The number of keyComparisons is 12608763
# hello
# The THRESHOLD size is 6276
# --- 3.281606912612915 seconds ---
# The number of keyComparisons is 12559425
# hello
# The THRESHOLD size is 6281
# --- 3.253308057785034 seconds ---
# The number of keyComparisons is 12594303
# hello
# The THRESHOLD size is 6286
# --- 3.2410993576049805 seconds ---
# The number of keyComparisons is 12588647
# hello
# The THRESHOLD size is 6291
# --- 3.19250226020813 seconds ---
# The number of keyComparisons is 12432334
# hello
# The THRESHOLD size is 6296
# --- 3.3531274795532227 seconds ---
# The number of keyComparisons is 12544077
# hello
# The THRESHOLD size is 6301
# --- 3.2832703590393066 seconds ---
# The number of keyComparisons is 12559345
# hello
# The THRESHOLD size is 6306
# --- 3.3224308490753174 seconds ---
# The number of keyComparisons is 12576286
# hello
# The THRESHOLD size is 6311
# --- 3.2214930057525635 seconds ---
# The number of keyComparisons is 12430245
# hello
# The THRESHOLD size is 6316
# --- 3.335088014602661 seconds ---
# The number of keyComparisons is 12665981
# hello
# The THRESHOLD size is 6321
# --- 3.2279796600341797 seconds ---
# The number of keyComparisons is 12654398
# hello
# The THRESHOLD size is 6326
# --- 3.283018112182617 seconds ---
# The number of keyComparisons is 12658364
# hello
# The THRESHOLD size is 6331
# --- 3.4633066654205322 seconds ---
# The number of keyComparisons is 12478326
# hello
# The THRESHOLD size is 6336
# --- 3.3326547145843506 seconds ---
# The number of keyComparisons is 12392937
# hello
# The THRESHOLD size is 6341
# --- 3.27738881111145 seconds ---
# The number of keyComparisons is 12494352
# hello
# The THRESHOLD size is 6346
# --- 3.505089282989502 seconds ---
# The number of keyComparisons is 12405491
# hello
# The THRESHOLD size is 6351
# --- 3.349104404449463 seconds ---
# The number of keyComparisons is 12639947
# hello
# The THRESHOLD size is 6356
# --- 3.1871063709259033 seconds ---
# The number of keyComparisons is 12454966
# hello
# The THRESHOLD size is 6361
# --- 3.324307680130005 seconds ---
# The number of keyComparisons is 12554537
# hello
# The THRESHOLD size is 6366
# --- 3.820591688156128 seconds ---
# The number of keyComparisons is 12437375
# hello
# The THRESHOLD size is 6371
# --- 4.115626573562622 seconds ---
# The number of keyComparisons is 12498438
# hello
# The THRESHOLD size is 6376
# --- 3.6911046504974365 seconds ---
# The number of keyComparisons is 12533067
# hello
# The THRESHOLD size is 6381
# --- 3.3588554859161377 seconds ---
# The number of keyComparisons is 12347695
# hello
# The THRESHOLD size is 6386
# --- 3.537966251373291 seconds ---
# The number of keyComparisons is 12646571
# hello
# The THRESHOLD size is 6391
# --- 3.3332855701446533 seconds ---
# The number of keyComparisons is 12484823
# hello
# The THRESHOLD size is 6396
# --- 3.340803623199463 seconds ---
# The number of keyComparisons is 12504927
# hello
# The THRESHOLD size is 6401
# --- 3.224405288696289 seconds ---
# The number of keyComparisons is 12486421
# hello
# The THRESHOLD size is 6406
# --- 3.21301007270813 seconds ---
# The number of keyComparisons is 12521181
# hello
# The THRESHOLD size is 6411
# --- 3.3708672523498535 seconds ---
# The number of keyComparisons is 12401293
# hello
# The THRESHOLD size is 6416
# --- 3.551872730255127 seconds ---
# The number of keyComparisons is 12584138
# hello
# The THRESHOLD size is 6421
# --- 3.456101655960083 seconds ---
# The number of keyComparisons is 12584307
# hello
# The THRESHOLD size is 6426
# --- 3.363621234893799 seconds ---
# The number of keyComparisons is 12507488
# hello
# The THRESHOLD size is 6431
# --- 3.473987340927124 seconds ---
# The number of keyComparisons is 12738646
# hello
# The THRESHOLD size is 6436
# --- 3.2013301849365234 seconds ---
# The number of keyComparisons is 12496873
# hello
# The THRESHOLD size is 6441
# --- 3.1831023693084717 seconds ---
# The number of keyComparisons is 12457673
# hello
# The THRESHOLD size is 6446
# --- 3.3863418102264404 seconds ---
# The number of keyComparisons is 12635178
# hello
# The THRESHOLD size is 6451
# --- 3.4084150791168213 seconds ---
# The number of keyComparisons is 12585405
# hello
# The THRESHOLD size is 6456
# --- 3.4420933723449707 seconds ---
# The number of keyComparisons is 12542328
# hello
# The THRESHOLD size is 6461
# --- 3.34954571723938 seconds ---
# The number of keyComparisons is 12549146
# hello
# The THRESHOLD size is 6466
# --- 3.5421268939971924 seconds ---
# The number of keyComparisons is 12555492
# hello
# The THRESHOLD size is 6471
# --- 3.2878916263580322 seconds ---
# The number of keyComparisons is 12624859
# hello
# The THRESHOLD size is 6476
# --- 3.3006680011749268 seconds ---
# The number of keyComparisons is 12580328
# hello
# The THRESHOLD size is 6481
# --- 3.319969892501831 seconds ---
# The number of keyComparisons is 12650135
# hello
# The THRESHOLD size is 6486
# --- 3.250727415084839 seconds ---
# The number of keyComparisons is 12339575
# hello
# The THRESHOLD size is 6491
# --- 3.2440977096557617 seconds ---
# The number of keyComparisons is 12386245
# hello
# The THRESHOLD size is 6496
# --- 3.3067965507507324 seconds ---
# The number of keyComparisons is 12579441
# hello
# The THRESHOLD size is 6501
# --- 3.3669984340667725 seconds ---
# The number of keyComparisons is 12636450
# hello
# The THRESHOLD size is 6506
# --- 3.286421775817871 seconds ---
# The number of keyComparisons is 12531142
# hello
# The THRESHOLD size is 6511
# --- 3.3617303371429443 seconds ---
# The number of keyComparisons is 12518403
# hello
# The THRESHOLD size is 6516
# --- 3.644335985183716 seconds ---
# The number of keyComparisons is 12470283
# hello
# The THRESHOLD size is 6521
# --- 3.54682993888855 seconds ---
# The number of keyComparisons is 12506431
# hello
# The THRESHOLD size is 6526
# --- 3.855052947998047 seconds ---
# The number of keyComparisons is 12491397
# hello
# The THRESHOLD size is 6531
# --- 3.278106212615967 seconds ---
# The number of keyComparisons is 12527692
# hello
# The THRESHOLD size is 6536
# --- 3.6106457710266113 seconds ---
# The number of keyComparisons is 12627014
# hello
# The THRESHOLD size is 6541
# --- 3.1951334476470947 seconds ---
# The number of keyComparisons is 12388646
# hello
# The THRESHOLD size is 6546
# --- 3.2171857357025146 seconds ---
# The number of keyComparisons is 12423958
# hello
# The THRESHOLD size is 6551
# --- 3.298731565475464 seconds ---
# The number of keyComparisons is 12599436
# hello
# The THRESHOLD size is 6556
# --- 3.2588047981262207 seconds ---
# The number of keyComparisons is 12661369
# hello
# The THRESHOLD size is 6561
# --- 3.3323819637298584 seconds ---
# The number of keyComparisons is 12543882
# hello
# The THRESHOLD size is 6566
# --- 3.308628559112549 seconds ---
# The number of keyComparisons is 12441754
# hello
# The THRESHOLD size is 6571
# --- 3.3046624660491943 seconds ---
# The number of keyComparisons is 12489222
# hello
# The THRESHOLD size is 6576
# --- 3.494215965270996 seconds ---
# The number of keyComparisons is 12653943
# hello
# The THRESHOLD size is 6581
# --- 3.670802116394043 seconds ---
# The number of keyComparisons is 12341428
# hello
# The THRESHOLD size is 6586
# --- 3.7706246376037598 seconds ---
# The number of keyComparisons is 12534501
# hello
# The THRESHOLD size is 6591
# --- 3.7627487182617188 seconds ---
# The number of keyComparisons is 12576344
# hello
# The THRESHOLD size is 6596
# --- 3.356882333755493 seconds ---
# The number of keyComparisons is 12537798
# hello
# The THRESHOLD size is 6601
# --- 3.481231927871704 seconds ---
# The number of keyComparisons is 12515512
# hello
# The THRESHOLD size is 6606
# --- 3.612846612930298 seconds ---
# The number of keyComparisons is 12446411
# hello
# The THRESHOLD size is 6611
# --- 3.279149055480957 seconds ---
# The number of keyComparisons is 12523810
# hello
# The THRESHOLD size is 6616
# --- 3.3909897804260254 seconds ---
# The number of keyComparisons is 12543688
# hello
# The THRESHOLD size is 6621
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25864\1300580313.py in <module>
#       7
#       8     #run the driver function and save the results into a dictionary
# ----> 9     results2[THRESHOLD]=driver(inputSize,THRESHOLD)
#      10 #     #driver(inputSize)
#      11
#
# ~\AppData\Local\Temp\ipykernel_25864\4039095257.py in driver(inputSize, THRESHOLD)
#      26     start_time = time.time()
#      27     #sorted=mergeSort(array,0,len(array)-1)
# ---> 28     sorted=hybridSort(array,THRESHOLD)
#      29     print("--- %s seconds ---" % (time.time() - start_time))
#      30
#
# ~\AppData\Local\Temp\ipykernel_25864\4039095257.py in hybridSort(array, THRESHOLD)
#      46         secondhalf = array[mid:]
#      47         left = hybridSort(firsthalf,THRESHOLD)
# ---> 48         right = hybridSort(secondhalf,THRESHOLD)
#      49         final=merge(left,right)
#      50         return final
#
# ~\AppData\Local\Temp\ipykernel_25864\4039095257.py in hybridSort(array, THRESHOLD)
#      39     #THRESHOLD CANNOT BE 0 else the below condition will never take place and will result in infinite loop
#      40     if len(array) <=THRESHOLD:
# ---> 41         insertionSort(array)
#      42         return array
#      43     else:
#
# ~\AppData\Local\Temp\ipykernel_25864\4039095257.py in insertionSort(array)
#      88             if array[j]< array[j-1]:
#      89                 keyComparisons += 1
# ---> 90                 array[j],array[j-1]=array[j-1],array[j]
#      91             else:
#      92                 keyComparisons += 1
#
# KeyboardInterrupt:

# %%
plots2=pd.DataFrame(results2.items(), columns=['Threshold', 'keyComparisons'])
plots2
# Out:
#       Threshold  keyComparisons
# 0             1          120483
# 1             6          121489
# 2            11          126972
# 3            16          127064
# 4            21          143320
# ...         ...             ...
# 1319       6596        12537798
# 1320       6601        12515512
# 1321       6606        12446411
# 1322       6611        12523810
# 1323       6616        12543688
#
# [1324 rows x 2 columns]

# %%
f=plt.figure(figsize=(7,7))
finish=sb.lineplot(x=plots2["Threshold"],y=plots2["keyComparisons"])
n_values = plots2["inputSize"]
nlogn_values = n_values * np.log(n_values)

# Plot the nlog(n) curve
plt.plot(n_values, nlogn_values, label="nlog(n)", color='red')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'inputSize'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25864\3389313515.py in <module>
#       1 f=plt.figure(figsize=(7,7))
#       2 finish=sb.lineplot(x=plots2["Threshold"],y=plots2["keyComparisons"])
# ----> 3 n_values = plots2["inputSize"]
#       4 nlogn_values = n_values * np.log(n_values)
#       5
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'inputSize'
